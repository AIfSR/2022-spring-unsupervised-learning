# %%
from AIfSR_Trajectory_Analysis.Trajectory_Analysis import quick_train
from AIfSR_Trajectory_Analysis.features.ThreeDMSDFeatureCreator import ThreeDMSDFeatureCreator

quick_train([(ThreeDMSDFeatureCreator(), 20)])
# Out:
# Getting points
# Extracting Features:
# 0 / 16  trajectory's features extracted
# min(feature):  6.967650591832242e-07
# 1 / 16  trajectory's features extracted
# min(feature):  6.967650591832241e-07
# 2 / 16  trajectory's features extracted
# min(feature):  6.967650591832241e-07
# 3 / 16  trajectory's features extracted
# min(feature):  6.967650591832243e-07
# 4 / 16  trajectory's features extracted
# min(feature):  0.466443554652483
# 5 / 16  trajectory's features extracted
# min(feature):  0.2728842832469763
# 6 / 16  trajectory's features extracted
# min(feature):  0.3765017814234811
# 7 / 16  trajectory's features extracted
# min(feature):  0.5525666890831654
# 8 / 16  trajectory's features extracted
# min(feature):  0.0009350666882661059
# 9 / 16  trajectory's features extracted
# min(feature):  0.0005682431587331894
# 10 / 16  trajectory's features extracted
# min(feature):  0.000984180342299753
# 11 / 16  trajectory's features extracted
# min(feature):  0.00019343185385675314
# 12 / 16  trajectory's features extracted
# min(feature):  0.26753472222222335
# 13 / 16  trajectory's features extracted
# min(feature):  0.3432911392405063
# 14 / 16  trajectory's features extracted
# min(feature):  0.3529645760743325
# 15 / 16  trajectory's features extracted
# min(feature):  0.29138722202611517
# Training Algorithm
# Training Accuracy: 1.0
# Test Accuracy: 1.0
# Here are a few graphs of the features used:
