# %%
from AIfSR_Trajectory_Analysis.Trajectory_Analysis import quick_train
from AIfSR_Trajectory_Analysis.features.ThreeDMSDFeatureCreator import ThreeDMSDFeatureCreator
from AIfSR_Trajectory_Analysis.features.MSDFeatureCreator import MSDFeatureCreator
from AIfSR_Trajectory_Analysis.features.XFeatureCreator import XFeatureCreator
from AIfSR_Trajectory_Analysis.features.YFeatureCreator import YFeatureCreator
from AIfSR_Trajectory_Analysis.features.ZFeatureCreator import ZFeatureCreator
from AIfSR_Trajectory_Analysis.features.RateOfChangeFeatureCreator import RateOfChangeFeatureCreator
from AIfSR_Trajectory_Analysis.features.XYZSpeedFeatureCreator import XYZSpeedFeatureCreator
from AIfSR_Trajectory_Analysis.features.PointsAngleFeatureCreator import PointsAngleFeatureCreator

quick_train([
    (ThreeDMSDFeatureCreator(), 40), 
    (MSDFeatureCreator(XFeatureCreator()), 0),
    (MSDFeatureCreator(YFeatureCreator()), 0),
    (MSDFeatureCreator(ZFeatureCreator()), 0),
    (RateOfChangeFeatureCreator(XFeatureCreator()), 0),
    (RateOfChangeFeatureCreator(YFeatureCreator()), 0),
    (RateOfChangeFeatureCreator(ZFeatureCreator()), 0),
    (XYZSpeedFeatureCreator(), 0),
    (PointsAngleFeatureCreator(), 0),
], trajectoriesPerCategory=200, graphsPerCategory=3)
# Out:
# Loading trajectories
#
# Extracting Features:
# 0 / 800  trajectory's features extracted
# 160 / 800  trajectory's features extracted
# 320 / 800  trajectory's features extracted
# 480 / 800  trajectory's features extracted
# 640 / 800  trajectory's features extracted
#
# Training Algorithm on  640  trajectories
# Training Accuracy: 0.9703125
# Testing Algorithm on  160  trajectories
# Test Accuracy:  0.95625
#
# Here are a few graphs of the features generated:
